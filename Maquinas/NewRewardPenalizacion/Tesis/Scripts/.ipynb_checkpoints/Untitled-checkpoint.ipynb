# %%
import pandas as pd
import matplotlib.pyplot as plt 
dt = pd.read_csv('20220105-131532-SimpleReward.csv')
df = dt['endCause'].value_counts()
print(df)
df.plot(kind = 'bar')
plt.show
# Out:
# reached goal                 75
# max iterations               43
# collide with an obstacule    31
# out of bounds                 6
# Name: endCause, dtype: int64
# <function matplotlib.pyplot.show(close=None, block=None)>
